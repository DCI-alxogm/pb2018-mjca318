# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline     
#para activar los graficos en el notebook

# %%
fx=lambda x,y: x**2*np.cos(x/y)-3*x**3

# %%
#opcion 2 para definir funciones 
def fx2(x,y):
    z=x*y*np.cos(x/y)-3*x**3
    return z

# %%
x=np.linspace(-10,10,100)
x2=np.linspace(0,5,100)
y=x**2*np.cos(x)*-3*x**3
y2=x2**2*np.cos(x2)*-3*x2**3
z=fx(x,y)

# %%
plt.plot(x,z)
#plt.plot(x2,y2)

# %%
x3=np.random.rand(10)
fx2(x3,2)
# Out:
# array([ 0.60086927,  0.28273499,  0.05378625,  0.25108957,  0.57474178,
#         0.28198805, -1.0925608 ,  0.51621659,  0.40606148,  0.17309062])

# %%
def recta(a,m=1,b=0,label='x'):
    z=m*a+b
    plt.plot(a,z,label=label)
    return

# %%
x=np.linspace(-2,2,20)
recta(x)
recta(x,-2,1,'-x+1')
plt.legend()

plt.grid()
